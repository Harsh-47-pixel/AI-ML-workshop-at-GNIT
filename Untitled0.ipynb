# %%
a=int(input("enter the first number"))
b=int(input("enter the secomd number"))
print("additionis",a+b)
print("subtraction is",a-b)
print("multiplication is",a*b)
print("division is",a/b)
# Out:
# enter the first number8
# enter the secomd number5
# additionis 13
# subtraction is 3
# multiplication is 40
# division is 1.6

# %%
#student info
name=input ("enter your name:")
age=int(input("enter your age:"))
department=input("enter your department:")
print(f"my name is{name},age is{age},department{department}")
# Out:
# enter your name:harsh kumar singh
# enter your age:19
# enter your department:ECE
# my name isharsh kumar singh,age is19,departmentECE

# %%
a=float(input())
b=float(input())
print(a+b)
# Out:
# 7
# 6
# 13.0

# %%
#popular data types in python
#list vs tuple
roles=["AI Engineer","freelance sof developer","desiger","tester"]

# %%
#if else statements
age=int(input("enter your age:"))
if age>18:
  print("you can drive")
else:
    print("you can't drive")
# Out:
# enter your age:21
# you can drive

# %%
#if-else statements & identation
#lets find greatest among three numbers
a=int(input("enter a:"))
b=int(input("enter b:"))
c=int(input("enter c:"))
if a>b and a>c:
  print("a is greatest")
elif b>a and b>c:
  print("b is greatest")
else:
  print("c is greatest")
# Out:
# enter a:4
# enter b:1
# enter c:9
# c is greatest

# %%
#modules
import math
a=25
print(math.sqrt(a))
# Out:
# 5.0

# %%
#how camn you print the current date & time?
import datetime
a=datetime.datetime.now()
print(a)
# Out:
# 2026-03-16 07:23:25.734337
